# %%
# Update to include more diverse addresses, comments, and add 'Non-binary' to gender options
import random
import json
# Expanded list of addresses in Châtenay-Malabry with corresponding latitudes and longitudes
addresses = [
    {"address": "60 Avenue Léon Blum, 92290 Châtenay-Malabry, France", "latitude": 48.756409, "longitude": 2.263818},
    {"address": "144 Rue des Écoles, 92290 Châtenay-Malabry, France", "latitude": 48.766566, "longitude": 2.262378},
    {"address": "109 Rue Anatole France, 92290 Châtenay-Malabry, France", "latitude": 48.765342, "longitude": 2.297736},
    {"address": "97 Boulevard des Étudiants, 92290 Châtenay-Malabry, France", "latitude": 48.769119, "longitude": 2.292927},
    {"address": "61 Chemin de la Vallée aux Loups, 92290 Châtenay-Malabry, France", "latitude": 48.758537, "longitude": 2.296931},
    {"address": "125 Rue Anatole France, 92290 Châtenay-Malabry, France", "latitude": 48.752885, "longitude": 2.256264},
    {"address": "141 Avenue Jean Jaurès, 92290 Châtenay-Malabry, France", "latitude": 48.767728, "longitude": 2.277298},
    {"address": "116 Avenue Jean Jaurès, 92290 Châtenay-Malabry, France", "latitude": 48.751451, "longitude": 2.291243},
    {"address": "135 Avenue Victor Hugo, 92290 Châtenay-Malabry, France", "latitude": 48.761917, "longitude": 2.290144},
    {"address": "99 Place de la Liberté, 92290 Châtenay-Malabry, France", "latitude": 48.755453, "longitude": 2.27703},
    {"address": "143 Chemin de la Vallée aux Loups, 92290 Châtenay-Malabry, France", "latitude": 48.750319, "longitude": 2.298167},
    {"address": "50 Rue des Peupliers, 92290 Châtenay-Malabry, France", "latitude": 48.757015, "longitude": 2.267142},
    {"address": "89 Rue Paul Vaillant-Couturier, 92290 Châtenay-Malabry, France", "latitude": 48.760294, "longitude": 2.297018},
    {"address": "100 Chemin de la Vallée aux Loups, 92290 Châtenay-Malabry, France", "latitude": 48.766428, "longitude": 2.275902},
    {"address": "125 Rue Paul Vaillant-Couturier, 92290 Châtenay-Malabry, France", "latitude": 48.754479, "longitude": 2.290159},
    {"address": "44 Place de la Liberté, 92290 Châtenay-Malabry, France", "latitude": 48.760962, "longitude": 2.252406},
]

# Updated function to generate a random number of demands for each user
def generate_user_data_v3(num_users=100):
    first_names = ['Lucas', 'Léa', 'Emma', 'Louis', 'Chloé', 'Nathan', 'Julie', 'Alexandre', 'Manon', 'Maxime', 'Sarah', 'Paul', 'Marie', 'Thomas', 'Camille', 'Enzo', 'Lucie', 'Mathieu', 'Clara', 'Jules', 'Lola', 'Antoine', 'Laura', 'Hugo', 'Sophie', 'Arthur', 'Eva', 'Léo', 'Noémie', 'Pierre', 'Alice', 'Martin', 'Elisa', 'Gabriel', 'Céline', 'Adrien', 'Inès', 'Romain', 'Anna', 'Matthieu', 'Zoé', 'Julien', 'Marine', 'Lina', 'Baptiste', 'Charlotte', 'Oscar', 'Margaux', 'David', 'Amandine', 'Valentin', 'Florian', 'Nina', 'Quentin', 'Eva', 'Noah', 'Salomé', 'Ethan', 'Émilie', 'Raphaël', 'Jade', 'Lucas', 'Juliette', 'Théo', 'Sacha', 'Benoît', 'Louise', 'Vincent', 'Maël', 'Elodie', 'Guillaume', 'Nicolas', 'Clément', 'Lina', 'Aurélie', 'Emma', 'Hélène', 'Roxane', 'Damien', 'Sarah', 'Hugo', 'Julie', 'Thibault', 'Gaëlle', 'Léonie', 'Samuel', 'Sébastien', 'Isabelle', 'Mélissa', 'Éloïse', 'Mathis', 'Elsa', 'Lucas', 'Cédric', 'Solène', 'Anaïs', 'Thomas', 'Manuel', 'Amélie', 'Thérèse']
    last_names = ['Martin', 'Bernard', 'Dubois', 'Thomas', 'Robert', 'Richard', 'Petit', 'Durand', 'Leroy', 'Moreau', 'Simon', 'Laurent', 'Lefebvre', 'Michel', 'Garcia', 'David', 'Bertrand', 'Roux', 'Vincent', 'Fournier', 'Morel', 'Girard', 'André', 'Lemoine', 'Dupont', 'Lambert', 'Bonnet', 'Francois', 'Martinez', 'Legrand', 'Gauthier', 'Perrin', 'Robin', 'Clement', 'Morin', 'Nicolas', 'Henry', 'Roussel', 'Mathieu', 'Garnier', 'Chevalier', 'Renaud', 'Gaillard', 'Barbier', 'Arnaud', 'Leclerc', 'Payet', 'Dufour', 'Benoit', 'Paris', 'Meyer', 'Blanc', 'Guillaume', 'Poirier', 'Martins', 'Maillard', 'Marchand', 'Duval', 'Brun', 'Lopez', 'Fontaine', 'Rossi', 'Brunet', 'Caron', 'Bailly', 'Clerc', 'Giraud', 'Lemoine', 'Jacquet', 'Olivier', 'Rodriguez', 'Collet', 'Renard', 'Gonzalez', 'Fabre', 'Meunier', 'Blanchard', 'Tessier', 'Picard', 'Jean', 'Pires', 'Rey', 'Gomez', 'Marty', 'Huet', 'Baron', 'Da Silva', 'Carpentier', 'Leclercq', 'Bourgeois', 'Dupuy', 'Berger', 'Louis', 'Roy', 'Philippe', 'Royer', 'Schmitt', 'Adam', 'Gallet']
    professions = ['Engineer', 'Doctor', 'Artist', 'Photographer', 'Lawyer', 'Chef', 'Designer']
    genders = ['Male', 'Female', 'Non-binary']
    status_choices = ['Gen+', 'GenDemandeur']
    service_tags = ['Aide au jardinage', 'Aide aux devoirs', 'Aide à la couture', 'Coaching sportif', 'Cours de musique', 'Covoiturage', 'Cuisine à domicile', 'Don de vêtements', 'Dépannage informatique', "Garde d'animaux", 'Partage de repas', 'Prêt de livres', 'Prêt de matériel de bricolage', "Réparation d'électroménagers", 'Travaux de peinture']
    comments_list =['Très satisfait du service !', 'Je recommande vivement.', 'Expérience mitigée.', 'Excellente prestation.', 'Un peu déçu du résultat.', 'Le personnel est très accueillant.', 'Rapport qualité/prix imbattable.', 'Service rapide et efficace.', 'Produit conforme à la description.', 'Je reviendrai sans hésiter.', 'Le suivi client laisse à désirer.', 'Un service professionnel et à l’écoute.', 'Des délais un peu longs.', 'Le produit est arrivé endommagé.', 'Support client réactif.', 'Je suis très satisfait de mon achat.', 'A éviter, mauvaise expérience.', 'Un service de qualité, je recommande.', 'Le produit ne fonctionne pas.', 'Bonne communication tout au long de l’achat.', 'Produit de mauvaise qualité.', 'Livraison rapide et soignée.', 'Je ne suis pas satisfait du tout.', 'Un très bon rapport qualité/prix.', 'Produit impeccable.', 'Excellent service après-vente.', 'Pas à la hauteur de mes attentes.', 'Produit de très bonne facture.', 'Le site est très facile à utiliser.', 'Je suis vraiment déçu de cet achat.', 'Merci pour votre professionnalisme.', 'Livraison plus rapide que prévue.', 'Produit conforme et bien emballé.', 'Un service client au top.', 'Expérience client exceptionnelle.', 'Je suis mécontent du produit.', 'Très bon rapport qualité/prix.', 'Le produit est arrivé en retard.', 'Je suis satisfait du service.', 'Site très intuitif.', 'Le produit ne correspond pas à mes attentes.', 'Un peu cher pour ce que c’est.', 'Produit très fonctionnel.', 'Très bon accueil et suivi.', 'Je suis globalement satisfait.', 'Problème lors de la livraison.', 'Rien à dire, tout est parfait.', 'Très bonne communication.', 'Produit de mauvaise qualité.', 'Le produit est top !', 'Je recommande sans hésiter.', 'Expérience décevante.', 'Service client non réactif.', 'Produit défectueux à l’arrivée.', 'Livraison dans les temps.', 'Tout s’est bien passé.', 'Satisfait de mon achat.', 'Je déconseille fortement ce site.', 'Le produit est abîmé.', 'Excellente communication.', 'Produit parfaitement emballé.', 'Très bonne réactivité.', 'Produit conforme à la commande.', 'Un service client irréprochable.', 'Très déçu de mon expérience.', 'Je recommande les yeux fermés.', 'Produit à éviter, mauvaise qualité.', 'Produit qui ne fonctionne pas du tout.', 'Service excellent.', 'Livraison impeccable et rapide.', 'Produit très bien conditionné.', 'Très satisfait de mon achat.', 'Le produit a été livré en retard.', 'Très déçu par la qualité du service.', 'Achat conforme à mes attentes.', 'Je suis ravi de cet achat.', 'Service client incompétent.', 'Expérience utilisateur désastreuse.', 'Je ne recommande pas ce site.', 'Le service client est top.', 'Produit arrivé en parfait état.', 'Le produit ne correspond pas à la description.', 'Déçu du service après-vente.', 'Je ne suis pas convaincu.', 'Bon produit, mais livraison tardive.', 'Parfait pour ce que j’en attendais.', 'Produit très décevant.', 'Bonne expérience utilisateur.', 'Site facile à naviguer.', 'Service de qualité.']

    data = []

    for i in range(num_users):
        first_name = random.choice(first_names)
        last_name = random.choice(last_names)
        profession = random.choice(professions)
        age = random.randint(20, 70)
        gender = random.choice(genders)
        address_data = random.choice(addresses)
        status = random.choice(status_choices)
        service_tag = random.choice(service_tags)
        points = random.randint(0, 500)

        # Generate a random number of demands (between 1 and 5)
        num_demands = random.randint(1, 5)
        demands = []
        for j in range(num_demands):
            demand = {
                'numero': j + 1,
                'tag': service_tag,
                'description': f'Service de {service_tag}',
                'date': random.choice(['2023-01-01', '2024-09-30', '2024-04-23', '2023-08-01']),
                'statut': random.choice(['actif', 'terminé'])
            }
            demands.append(demand)

        comments = random.choice(comments_list)

        user = {
            'First Name': first_name,
            'Last Name': last_name,
            'Profession': profession,
            'Age': age,
            'Gender': gender,
            'Address': address_data['address'],
            'Latitude': address_data['latitude'],
            'Longitude': address_data['longitude'],
            'Service Tag': service_tag,
            'Email': f'{first_name.lower()}{last_name.lower()}@gmail.com',
            'Password': '1234',
            'Status': status,
            'Demands': demands,
            'Commentaires': comments,
            'Points': points
        }

        data.append(user)

    return data

# Generate 100 users with a random number of demands
user_data_v3 = generate_user_data_v3(100)

# Save to a new JSON file
file_path_v3 = "fake_users_v5.json"
with open(file_path_v3, 'w') as f:
    json.dump(user_data_v3, f, indent=4)

file_path_v3
# Out:
# 'fake_users_v5.json'
